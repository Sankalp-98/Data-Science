# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')
df_train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # Check missing data in df_train

# %%
df_train.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df_train.fillna(0,inplace=True)
df_train.isna().any()
# Out:
# User_ID                       False
# Product_ID                    False
# Gender                        False
# Age                           False
# Occupation                    False
# City_Category                 False
# Stay_In_Current_City_Years    False
# Marital_Status                False
# Product_Category_1            False
# Product_Category_2            False
# Product_Category_3            False
# Purchase                      False
# dtype: bool

# %% [markdown]
# # Check missing data in df_test

# %%
df_test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_test.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df_test.fillna(0,inplace=True)

# %% [markdown]
# # EDA on df_train

# %%
df_train.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df_train['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
df_train['City_Category'].value_counts()
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %%
df_train['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df_train['User_ID'] = df_train['User_ID'] - 1000000
df_test['User_ID'] = df_test['User_ID'] - 1000000
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0        1  P00069042      F  0-17          10             A
# 1        1  P00248942      F  0-17          10             A
# 2        1  P00087842      F  0-17          10             A
# 3        1  P00085442      F  0-17          10             A
# 4        2  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0        4  P00128942      M  46-50           7             B
# 1        9  P00113442      M  26-35          17             C
# 2       10  P00288442      F  36-45           1             B
# 3       10  P00145342      F  36-45           1             B
# 4       11  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 0.0
# 1                 5.0                 0.0
# 2                14.0                 0.0
# ...

# %%
df_train['Product_ID'] = df_train['Product_ID'].str.replace('P00','')
df_test['Product_ID'] = df_test['Product_ID'].str.replace('P00','')

df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0        1     069042      F  0-17          10             A
# 1        1     248942      F  0-17          10             A
# 2        1     087842      F  0-17          10             A
# 3        1     085442      F  0-17          10             A
# 4        2     285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_train['Age'] = df_train['Age'].map({'0-17': 15,
                               '18-25': 21,
                               '26-35': 30,
                               '36-45': 40,
                               '46-50': 48,
                               '51-55': 53,
                               '55+': 60})
df_test['Age'] = df_test['Age'].map({'0-17': 15,
                               '18-25': 21,
                               '26-35': 30,
                               '36-45': 40,
                               '46-50': 48,
                               '51-55': 53,
                               '55+': 60})

# %%
df_train['Stay_In_Current_City_Years']=df_train['Stay_In_Current_City_Years'].map({'0':0,'1':1,'2':2,'3':3,'4+':4})
df_train['Stay_In_Current_City_Years']
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         4
#          ..
# 550063    1
# 550064    3
# 550065    4
# 550066    2
# 550067    4
# Name: Stay_In_Current_City_Years, Length: 550068, dtype: int64

# %%
df_test['Stay_In_Current_City_Years']=df_test['Stay_In_Current_City_Years'].map({'0':0,'1':1,'2':2,'3':3,'4+':4})
df_test['Stay_In_Current_City_Years']
# Out:
# 0         2
# 1         0
# 2         4
# 3         4
# 4         1
#          ..
# 233594    4
# 233595    4
# 233596    4
# 233597    4
# 233598    4
# Name: Stay_In_Current_City_Years, Length: 233599, dtype: int64

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0        1     069042      F   15          10             A
# 1        1     248942      F   15          10             A
# 2        1     087842      F   15          10             A
# 3        1     085442      F   15          10             A
# 4        2     285442      M   60          16             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_test.head()
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0        4     128942      M   48           7             B
# 1        9     113442      M   30          17             C
# 2       10     288442      F   40           1             B
# 3       10     145342      F   40           1             B
# 4       11     053842      F   30           1             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               1                   1
# 1                           0               0                   3
# 2                           4               1                   5
# 3                           4               1                   4
# 4                           1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 0.0
# 1                 5.0                 0.0
# 2                14.0                 0.0
# ...

# %%
df_train['Product_ID']=df_train['Product_ID'].astype('int64')
df_test['Product_ID']=df_test['Product_ID'].astype('int64')

# %%
df_train.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                         object
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df_test.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                         object
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df_train['new']=encoder.fit_transform(df_train['City_Category'])
df_train['new']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         2
#          ..
# 550063    1
# 550064    2
# 550065    1
# 550066    2
# 550067    1
# Name: new, Length: 550068, dtype: int32

# %%
df_train.drop(columns='new',inplace=True)
df_train
# Out:
#         User_ID  Product_ID Gender  Age  Occupation City_Category  \
# 0             1       69042      F   15          10             A
# 1             1      248942      F   15          10             A
# 2             1       87842      F   15          10             A
# 3             1       85442      F   15          10             A
# 4             2      285442      M   60          16             C
# ...         ...         ...    ...  ...         ...           ...
# 550063     6033      372445      M   53          13             B
# 550064     6035      375436      F   30           1             C
# 550065     6036      375436      F   30          15             B
# 550066     6038      375436      F   60           1             C
# 550067     6039      371644      F   48           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# ...

# %%
train_dummy=pd.get_dummies(df_train,drop_first=True)
train_dummy
# Out:
#         User_ID  Product_ID  Age  Occupation  Stay_In_Current_City_Years  \
# 0             1       69042   15          10                           2
# 1             1      248942   15          10                           2
# 2             1       87842   15          10                           2
# 3             1       85442   15          10                           2
# 4             2      285442   60          16                           4
# ...         ...         ...  ...         ...                         ...
# 550063     6033      372445   53          13                           1
# 550064     6035      375436   30           1                           3
# 550065     6036      375436   30          15                           4
# 550066     6038      375436   60           1                           2
# 550067     6039      371644   48           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
train_dummy.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# Gender_M                        uint8
# City_Category_B                 uint8
# City_Category_C                 uint8
# dtype: object

# %%
test_dummy=pd.get_dummies(df_test,drop_first=True)
test_dummy
# Out:
#         User_ID  Product_ID  Age  Occupation  Stay_In_Current_City_Years  \
# 0             4      128942   48           7                           2
# 1             9      113442   30          17                           0
# 2            10      288442   40           1                           4
# 3            10      145342   40           1                           4
# 4            11       53842   30           1                           1
# ...         ...         ...  ...         ...                         ...
# 233594     6036      118942   30          15                           4
# 233595     6036      254642   30          15                           4
# 233596     6036       31842   30          15                           4
# 233597     6037      124742   48           1                           4
# 233598     6039      316642   48           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
test_dummy.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Gender_M                        uint8
# City_Category_B                 uint8
# City_Category_C                 uint8
# dtype: object

# %% [markdown]
# # Splitting train data

# %%
from sklearn.model_selection import train_test_split

# %%
X=train_dummy.drop(columns='Purchase')
y=train_dummy['Purchase']

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Scaling on training data

# %%
sc=StandardScaler()
X_new=pd.DataFrame(sc.fit_transform(X))
X_new.columns=X.columns
X_new.index=X.index

# %%
X_new
# Out:
#          User_ID  Product_ID       Age  Occupation  \
# 0      -1.752639   -1.028774 -1.741228    0.294864
# 1      -1.752639    0.722139 -1.741228    0.294864
# 2      -1.752639   -0.845799 -1.741228    0.294864
# 3      -1.752639   -0.869157 -1.741228    0.294864
# 4      -1.752061    1.077382  2.332202    1.214734
# ...          ...         ...       ...         ...
# 550063  1.738930    1.924156  1.698558    0.754799
# 550064  1.740087    1.953267 -0.383418   -1.084943
# 550065  1.740666    1.953267 -0.383418    1.061423
# 550066  1.741824    1.953267  2.332202   -1.084943
# 550067  1.742403    1.916360  1.245954   -1.238255
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                         0.109801       -0.833018           -0.610809
# 1                         0.109801       -0.833018           -1.118912
# 2                         0.109801       -0.833018            1.675656
# ...

# %% [markdown]
# Scaling on test data

# %%
sc=StandardScaler()
test=pd.DataFrame(sc.fit_transform(test_dummy))
test.columns=test_dummy.columns
test.index=test_dummy.index
test
# Out:
#          User_ID  Product_ID       Age  Occupation  \
# 0      -1.752305   -0.434752  1.247085   -0.166445
# 1      -1.749409   -0.587188 -0.385128    1.367031
# 2      -1.748830    1.133865  0.521657   -1.086530
# 3      -1.748830   -0.273465  0.521657   -1.086530
# 4      -1.748251   -1.173330 -0.385128   -1.086530
# ...          ...         ...       ...         ...
# 233594  1.741466   -0.533098 -0.385128    1.060336
# 233595  1.741466    0.801456 -0.385128    1.060336
# 233596  1.741466   -1.389691 -0.385128    1.060336
# 233597  1.742045   -0.476058  1.247085   -1.086530
# 233598  1.743204    1.411200  1.247085   -1.239878
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                         0.110432        1.199419           -1.144571
# 1                        -1.443264       -0.833737           -0.609292
# 2                         1.664128        1.199419           -0.074014
# ...

# %%
X_train,X_valid,y_train,y_valid=train_test_split(X_new,y,test_size=0.2,random_state=21)

# %% [markdown]
# # Model Training

# %% [markdown]
# 1)  LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lr.predict(X_valid)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
sqrt(mean_squared_error(pred,y_valid))
# Out:
# 4601.806236555765

# %% [markdown]
# 2) DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(min_samples_split=10,min_samples_leaf=3,random_state=21)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=21, splitter='best')

# %%
pred=dt.predict(X_valid)

# %%
sqrt(mean_squared_error(pred,y_valid))
# Out:
# 3216.451066512955

# %%
pred=dt.predict(test)

# %%
submission=pd.read_csv('sample_submission.csv')
submission['Purchase']=pred
submission.to_csv('DecisionTree.csv',index=False)

# %% [markdown]
# 3) RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=100,random_state=21)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=21, verbose=0,
#                       warm_start=False)

# %%
pred=rf.predict(X_valid)

# %%
sqrt(mean_squared_error(pred,y_valid))
# Out:
# 2732.3920609538927

# %%
pred=rf.predict(test)

# %%
submission=pd.read_csv('sample_submission.csv')
submission['Purchase']=pred
submission.to_csv('RandomForest.csv',index=False)

# %% [markdown]
# 4) XGBOOST

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor(random_state=21)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=21, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
pred=xgb.predict(X_valid)

# %%
sqrt(mean_squared_error(pred,y_valid))
# Out:
# 2735.3893207439664

# %%
pred=xgb.predict(test)

# %%
submission=pd.read_csv('sample_submission.csv')
submission['Purchase']=pred
submission.to_csv('Xgboost.csv',index=False)

# %% [markdown]
# 5) BAGGING REGRESSOR

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag=BaggingRegressor(base_estimator=RandomForestRegressor(min_samples_split=5,random_state=21),n_estimators=20,random_state=21)

# %%
bag.fit(X_train,y_train)
# Out:
# C:\Users\sanka\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\sanka\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\sanka\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\sanka\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
pred=bag.predict(X_valid)

# %%
sqrt(mean_squared_error(pred,y_valid))
# Out:
# 2668.85276484178

# %%
pred=bag.predict(test)

# %%
submission=pd.read_csv('sample_submission.csv')
submission['Purchase']=pred
submission.to_csv('Bag.csv',index=False)
